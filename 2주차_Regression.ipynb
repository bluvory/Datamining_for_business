# %% [markdown]
# # Linear Regression
# - 수치를 예측하는 것에 활용
# - 연속형 변수들인 독립변수와 종속변수 사이에 상관관계에 따른 수학적 모델인 선형 관계식을 구해 어떤 독립변수가 주어졌을때 이에 따른 종속변수의 값을 예측
# - 종속변수: 연속형인 수치 변수 / 독립변수: 연속형,범주형인 수치 데이터
# - 독립변수 하나: 단순 회귀 분석 / 여러개: 다중 회귀분석
# - 상관관계가 있는 변수 선택하기
# - 상관관계가 있다고 해서 두 변수간의 인과관계가 있다고 판단해서는 안됨
# - 모든 데이터에 대해 오차를 계산하고 오차의 합을 최소로 만드는 직선을 찾는것

# %% [markdown]
# ## 데이터 불러오기

# %%
import pandas as pd

movie = pd.read_csv('data/MoviePerformance.csv')
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           236 non-null    object
#  1   Grade           215 non-null    object
#  2   Length          229 non-null    float64
#  3   Genre           232 non-null    object
#  4   Rating          235 non-null    float64
#  5   Users           235 non-null    float64
#  6   BoxOfficeFirst  225 non-null    float64
#  7   ScreenFirst     225 non-null    float64
#  8   BoxOffice       235 non-null    float64
# dtypes: float64(6), object(3)
# memory usage: 16.7+ KB

# %%
movie['Genre'].value_counts()
# Out:
# Comedy       70
# Drama        62
# Action       39
# Adventure    12
# Horror       12
# Animation    11
# Crime        11
# Biography     9
# Musical       1
# Romance       1
# Western       1
# Fantasy       1
# History       1
# Sci-Fi        1
# Name: Genre, dtype: int64

# %%
movie2 = movie[movie['ScreenFirst'] > 500]

# %%
movie_train = movie2.iloc[0:80]
movie_test = movie2.iloc[80:]

# %%
len(movie_train)
# Out:
# 80

# %%
import matplotlib.pyplot as plt

plt.scatter(movie_train['ScreenFirst'], movie_train['BoxOffice'])
plt.xlabel('ScreenFirst')
plt.ylabel('BoxOffice')
plt.savefig('chap-regression-scatter.jpg',dpi=400,bbox_inches='tight')
plt.show()

# %%
from scipy.stats.stats import pearsonr

pearsonr(movie_train.ScreenFirst, movie_train.BoxOffice)
# Out:
# (0.5657943903868421, 4.526401745297524e-08)

# %% [markdown]
# - pearsonr: (상관계수, p-value)
# - ScreenFirst가 증가하면 BoxOffice가 증가하는 상관관계 있음을 알 수 있다
# - 상관관계 != 인과관계

# %% [markdown]
# ## 단순 회귀분석

# %%
import statsmodels.api as sm 

x = movie_train['ScreenFirst']
y = movie_train['BoxOffice']
X = sm.add_constant(x)

model = sm.OLS(y,X).fit()
predictions = model.predict(X)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              BoxOffice   R-squared:                       0.320
# Model:                            OLS   Adj. R-squared:                  0.311
# Method:                 Least Squares   F-statistic:                     36.73
# Date:                Wed, 16 Sep 2020   Prob (F-statistic):           4.53e-08
# Time:                        01:24:24   Log-Likelihood:                -1574.6
# No. Observations:                  80   AIC:                             3153.
# Df Residuals:                      78   BIC:                             3158.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -9.237e+07   3.38e+07     -2.730      0.008    -1.6e+08    -2.5e+07
# ScreenFirst  6.843e+04   1.13e+04      6.060      0.000     4.6e+04    9.09e+04
# ==============================================================================
# Omnibus:                       15.239   Durbin-Watson:                   0.831
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               17.452
# Skew:                           1.118   Prob(JB):                     0.000162
# Kurtosis:                       3.489   Cond. No.                     1.05e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.05e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### 결정계수
# - 종속변수의 총 변동에 대비해 회귀 모형이 얼마나 그 변동을 설명하는지
# - 0~1: 1에 가까울수록 회귀모형이 종속변수의 변동을 많이 설명

# %%
plt.scatter(x, y,  color='black')
plt.plot(x, predictions, color='blue', linewidth=3)
plt.xlabel('ScreenFirst')
plt.ylabel('BoxOffice')
plt.savefig('chap-regression-result.jpg',dpi=400,bbox_inches='tight')
plt.show()

# %%
import math

x_test = movie_test['ScreenFirst']
y_test = movie_test['BoxOffice']
X_test = sm.add_constant(x_test)  ## 절편 추가

test_prediction = model.predict(X_test) ## 예측치 생성

mae = sum( abs(test_prediction - y_test) / len(test_prediction))  ## 평균절대오차
rmse = math.sqrt( sum((test_prediction - y_test)**2) / len(test_prediction) ) ## 평균제곱근오차
mape = ((abs(test_prediction - y_test)/y_test)*100).mean() ## 평균절대퍼센티지오차

print('MAE : ', mae)
print('RMSE : ', rmse)
print('MAPE : ', mape)
# Out:
# MAE :  59127817.22077838
# RMSE :  74652771.40057965
# MAPE :  382.4899582731036

# %%
from sklearn.metrics import mean_squared_error

rmse = math.sqrt(mean_squared_error(test_prediction, y_test))
rmse
# Out:
# 74652771.40057965

# %% [markdown]
# ## 다중 회귀분석
# - 독립변수가 두 개인 경우는 오차를 최소로하는 어떤 면을 찾는 것, 추정해야하는 기울기 계수도 독립변수 수 만큼 증가
# - 독립변수 후보들 중에서 적합한 독립변수를 선택하는 단계

# %%
import statsmodels.api as sm 

x = movie_train[['ScreenFirst', 'BoxOfficeFirst', 'Rating', 'Users']]
y = movie_train['BoxOffice']
X = sm.add_constant(x)

model = sm.OLS(y,X).fit()
predictions = model.predict(X)

x_test = movie_test[['ScreenFirst', 'BoxOfficeFirst', 'Rating', 'Users']]
y_test = movie_test['BoxOffice']
X_test = sm.add_constant(x_test)  ## 절편 추가

test_prediction = model.predict(X_test) ## 예측치 생성

mae = sum( abs(test_prediction - y_test) / len(test_prediction))  ## 평균절대오차
rmse = math.sqrt( sum((test_prediction - y_test)**2) / len(test_prediction) ) ## 평균제곱근오차
mape = ((abs(test_prediction - y_test)/y_test)*100).mean() ## 평균절대퍼센티지오차

print('MAE : ', mae)
print('RMSE : ', rmse)
print('MAPE : ', mape)
# Out:
# MAE :  43939227.797135904
# RMSE :  57342220.813374504
# MAPE :  316.9356186878378

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              BoxOffice   R-squared:                       0.644
# Model:                            OLS   Adj. R-squared:                  0.625
# Method:                 Least Squares   F-statistic:                     33.88
# Date:                Wed, 16 Sep 2020   Prob (F-statistic):           3.90e-16
# Time:                        01:24:26   Log-Likelihood:                -1548.8
# No. Observations:                  80   AIC:                             3108.
# Df Residuals:                      75   BIC:                             3119.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const          -7.649e+07   4.57e+07     -1.672      0.099   -1.68e+08    1.46e+07
# ScreenFirst     3.967e+04   9149.658      4.335      0.000    2.14e+04    5.79e+04
# BoxOfficeFirst     1.4381      0.248      5.808      0.000       0.945       1.931
# Rating            1.3e+06   7.03e+06      0.185      0.854   -1.27e+07    1.53e+07
# Users            466.6243    166.750      2.798      0.007     134.441     798.808
# ==============================================================================
# Omnibus:                       27.070   Durbin-Watson:                   1.435
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.551
# Skew:                           1.390   Prob(JB):                     5.76e-10
# Kurtosis:                       5.244   Cond. No.                     2.72e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.72e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## 독립변수 선정

# %% [markdown]
# ### 시각화및 상관관계 계수 활용

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(movie_train, figsize = (6, 6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024C999428C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C999CDB48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99A089C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99A43888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99A7C708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99AB64C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99AED3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99B29108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99B29308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99B64288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99BCFD08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99C09BC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99C44A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99C7C908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99CB77C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99CF2588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99D2A448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99D662C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99DA0148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99DD4FC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99E0CDC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99E45C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99E7EB08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99EB9988>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99EF2848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99F2D648>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99F68508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99FA0388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C99FDA208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9A00DF88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9A0498C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9A084648>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9A0BC408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9A0F5188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9A127EC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9A161C08>]],
#       dtype=object)

# %%
movie_train.corr(method='pearson')
# Out:
#                   Length    Rating     Users  BoxOfficeFirst  ScreenFirst  \
# Length          1.000000  0.383731  0.431204        0.205573     0.083900
# Rating          0.383731  1.000000  0.600066        0.351505     0.213928
# Users           0.431204  0.600066  1.000000        0.416591     0.379393
# BoxOfficeFirst  0.205573  0.351505  0.416591        1.000000     0.300200
# ScreenFirst     0.083900  0.213928  0.379393        0.300200     1.000000
# BoxOffice       0.313850  0.401332  0.582753        0.664179     0.565794
#
#                 BoxOffice
# Length           0.313850
# Rating           0.401332
# Users            0.582753
# BoxOfficeFirst   0.664179
# ScreenFirst      0.565794
# BoxOffice        1.000000

# %%
import seaborn as sns 

plt.figure(figsize=(6,6))
cor = movie_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %% [markdown]
# ### 다중 공선성
# - 두 개 또는 그 이상의 독립변수들이 서로 밀접하게 상관되어 있는 경우
# - 10 이하면 다중공선성 문제가 없다

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(inputs):

    vif = pd.DataFrame()
    vif["variables"] = inputs.columns
    vif["VIF"] = [variance_inflation_factor(inputs.values, i) for i in range(inputs.shape[1])]

    return(vif)

calc_vif(x)
# Out:
#         variables        VIF
# 0     ScreenFirst  10.351665
# 1  BoxOfficeFirst   2.097737
# 2          Rating  10.946215
# 3           Users   2.148866

# %%
x_1 = movie_train[['ScreenFirst', 'BoxOfficeFirst', 'Users']]
calc_vif(x_1)
# Out:
#         variables       VIF
# 0     ScreenFirst  2.214435
# 1  BoxOfficeFirst  2.084525
# 2           Users  2.048384

# %% [markdown]
# ### 독립변수 제거 방안 (Wrapper method)

# %% [markdown]
# - 후진 제거법 Backward elimination

# %%
movie_train.head()
# Out:
#                      Title Grade  Length      Genre  Rating     Users  \
# 0        Ramona and Beezus    PG   103.0  Adventure     6.6    4274.0
# 1              Toy Story 3    PG   103.0  Animation     8.6  168181.0
# 22        Standing Ovation   NaN   105.0    Musical     3.1     174.0
# 29          Letters to God    PG   110.0      Drama     5.1    1718.0
# 30  Extraordinary Measures    PG   106.0      Drama     6.3    7133.0
#
#     BoxOfficeFirst  ScreenFirst    BoxOffice
# 0        7810481.0       2719.0   26161406.0
# 1      110307189.0       4028.0  414984497.0
# 22        343125.0        625.0     531806.0
# 29       1101204.0        897.0    2848578.0
# 30       6012594.0       2545.0   11854694.0

# %%
x = movie_train[['Length','ScreenFirst', 'BoxOfficeFirst', 'Rating', 'Users']]
y = movie_train['BoxOffice']
X = sm.add_constant(x)

model = sm.OLS(y,X).fit()
model.pvalues
# Out:
# const             4.623600e-02
# Length            2.210037e-01
# ScreenFirst       2.988469e-05
# BoxOfficeFirst    1.552957e-07
# Rating            9.814787e-01
# Users             2.099705e-02
# dtype: float64

# %%
X=X.drop(['Rating'],axis=1)
model=sm.OLS(y, X).fit()
model.pvalues
# Out:
# const             2.791602e-02
# Length            2.128935e-01
# ScreenFirst       2.617403e-05
# BoxOfficeFirst    1.025472e-07
# Users             9.872523e-03
# dtype: float64

# %%
X=X.drop(['Length'],axis=1)
model=sm.OLS(y, X).fit()
model.pvalues
# Out:
# const             7.167763e-03
# ScreenFirst       4.043731e-05
# BoxOfficeFirst    8.200554e-08
# Users             1.005283e-03
# dtype: float64

# %%
from sklearn.metrics import mean_squared_error

x_test = movie_test[['ScreenFirst', 'BoxOfficeFirst', 'Users']]
y_test = movie_test['BoxOffice']
X_test = sm.add_constant(x_test)  ## 절편 추가

test_prediction = model.predict(X_test) ## 예측치 생성

rmse = math.sqrt(mean_squared_error(test_prediction, y_test))
rmse
# Out:
# 57139129.88399198

# %% [markdown]
# ## 학습, 테스트 집합

# %%
import pandas as pd
import statsmodels.api as sm 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import math

movie = pd.read_csv('data/MoviePerformance.csv')
movie2 = movie[movie['ScreenFirst'] > 500]
x = movie2['ScreenFirst'] 
y = movie2['BoxOffice'] 
X = sm.add_constant(x) 

X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.2, random_state=None) 

model = sm.OLS(y_train, X_train).fit() 
predictions = model.predict(X_test)

rmse = math.sqrt(mean_squared_error(predictions, y_test))
rmse
# Out:
# 67409224.97114834

# %% [markdown]
# ## 교차검증
# - K겹 교차검증: 전체 데이터 집합을 학습 집합과 테스트 집합으로 나누어서 모형 학습에 학습 데이터 집합을 사용하고 학습된 모형의 성과를 평가하는 테스트 집합 활용

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

movie = pd.read_csv('data/MoviePerformance.csv')
movie2 = movie[movie['ScreenFirst'] > 500]
X = movie2[['ScreenFirst', 'BoxOfficeFirst', 'Users']] 
y = movie2['BoxOffice'] 

lin_reg = LinearRegression()
scores = cross_val_score(lin_reg, X, y, cv=5, scoring='neg_mean_absolute_error')

## neg_root_mean_squared_error

scores
# Out:
# array([-41756654.25873677, -51127554.98678496, -35806481.3871621 ,
#        -70691665.37988572, -41287617.45942156])

# %%
scores.mean()
# Out:
# -48133994.694398224

# %% [markdown]
# ## 연습 문제

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import math

# %%
boston = pd.read_csv("data/boston.csv")

# %%
boston.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %% [markdown]
# - Housing Values in Suburbs of Boston
#
# - ID: 지역 번호
# - crim: per capita crime rate by town (범죄율)
# - zn: proportion of residential land zoned for lots over 25,000 sq.ft. (주거지비율)
# - indus: proportion of non-retail business acres per town. (산업지비율)
# - chas: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise). (강 근접 여부)
# - nox: nitrogen oxides concentration (parts per 10 million) (질소산화물 농도)
# - rm: average number of rooms per dwelling. (평균 방 수)
# - age: proportion of owner-occupied units built prior to 1940. (1940년 이전에 지어진 주택의 비율)
# - dis: weighted mean of distances to five Boston employment centres. (주요 업무지구와의 평균 거리)
# - rad: index of accessibility to radial highways. (고속도로 접근성 지표)
# - tax: full-value property-tax rate per 10,000 U.S dollar. (세율)
# - ptratio: pupil-teacher ratio by town. (학생당 선생님 비율)
# - black: 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town (흑인 주거 비율)
# - lstat: lower status of the population (percent). (인구 중 하위 계층 비율)
# - medv: median value of owner-occupied homes in 1000 U.S dollars. (주택 가격 중앙값)

# %% [markdown]
# ## 데이터 탐색

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(boston, figsize = (12, 12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9BD5FE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9DDAC0C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9DDE15C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9DE17EC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9DE51D48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9DE89C08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9DEC2A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9DEFC788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9DEFC988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9DF37908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9DFA9488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9DFE2288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E015FC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E04EF88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E08AE08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E0C3CC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E0FDAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E137948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E171808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E1AC688>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E1E6508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E21F348>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E2591C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E28BF48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E2C3EC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E2FFD48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E339B88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E374A08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E3AE8C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E3E7788>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E41DD48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E456B08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E48F7C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E4C8548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E5022C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E536F48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E570DC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9DDB3B08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E05E748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E30DC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9B720208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9A6E8748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9A1A2148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E5EDF08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E628E88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E661D08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E69CBC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E6D49C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E70D888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E747708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E782588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E7BD448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E7F6248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E82BFC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E863F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E89EE08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E8D8CC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E911A88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E94B908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E9847C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E9BD648>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E9F8508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EA31308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EA6A188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EAA0F08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EADAE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EB12D48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EB4E548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EB872C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EBBBF48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EBF3E08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EC2EB88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EC68908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EC9F648>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9ECD83C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9ED12148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9ED43EC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9ED7DC48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EDB6988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EDF0708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EE284C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EE62248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EE96F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EECECC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EF08A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EF437C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EF7B548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EFB2308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EFE6F08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F01ED88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F056B48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F0908C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F0CA648>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F105408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9B74EBC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9E83BD88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9EB21548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F1C7508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F2003C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F23A1C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F26FF08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F2A9EC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F2E3D48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F31CBC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F355A08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F38F888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F3C9748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F4045C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F43D448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F478288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F4ABFC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F4E4F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F51DE08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F559C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F591AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F5CA948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F605808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F63F688>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F679508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F6B3348>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F6EE1C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F721F08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F75AEC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F794D48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F7D1488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F807208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F83AF48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F876CC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F8AFA88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F8E87C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F921548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F959308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F98DF48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F9C6DC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F9FFB88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FA39888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FA72608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FAAB388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FAE5148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FB14E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FB4EBC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FB8A988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FBC2708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FBFB488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FC33208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FC68F08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FCA0C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FCD8A08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FD147C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FD4E548>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FD85288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FDB7F08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FDEFD88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FE29B08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FE63888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FE9C648>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FED6348>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FF08F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FF42E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FF7BBC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9FFB4948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F199CC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F46CF48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024C9F6F9208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA00789C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA00B3848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA00EC688>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA0124548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA015E3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA0197288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA01CCFC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA0206EC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA0241D88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA027BC08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA02B5AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA02EF948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA0327748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA0362608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA039B488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA03D5348>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA040F1C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA0441F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA047CE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA04B5CC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA04F0B88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA0529A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA0563808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA059E6C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA05D6548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA06123C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA064B288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA0680A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA06B97C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA06F3588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA16FB308>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA172CF48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1765E08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA179EB08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA17D9888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1813648>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA184C3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1886148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA18B4E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA18EDC08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1928988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1963748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA199B508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA19D4308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1A06F08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1A3EDC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1A77B88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1AB2988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1AED748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1B254C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1B5F2C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1B8FF08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1BC5E08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1C00BC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1C3A948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1C75708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1CAF4C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1CE92C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1D19F08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1D51E08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CA1D8ABC8>]],
#       dtype=object)

# %% [markdown]
# - medv 와 상관관계가 보이는 변수 crim, indus, nox, rm, black, lstat

# %%
import seaborn as sns 

plt.figure(figsize=(12,12))
cor = boston.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %% [markdown]
# - age, dis, rad, tax, ptratio 도 상관관계 존재

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(inputs):

    vif = pd.DataFrame()
    vif["variables"] = inputs.columns
    vif["VIF"] = [variance_inflation_factor(inputs.values, i) for i in range(inputs.shape[1])]

    return(vif)

# %%
boston = boston.drop(['ID'], axis=1)

calc_vif(boston)
# Out:
#    variables         VIF
# 0       crim    2.650063
# 1         zn    2.617414
# 2      indus   13.808492
# 3       chas    1.166800
# 4        nox   75.661392
# 5         rm  135.373313
# 6        age   21.967034
# 7        dis   16.552909
# 8        rad   14.911887
# 9        tax   57.116414
# 10   ptratio   87.579721
# 11     black   24.585723
# 12     lstat   13.627317
# 13      medv   24.642917

# %%
x = boston.drop(['medv'],axis=1)
y = boston['medv']
X = sm.add_constant(x)

model = sm.OLS(y,X).fit()
model.pvalues
# Out:
# const      1.256136e-07
# crim       3.299747e-01
# zn         5.344095e-03
# indus      4.687111e-01
# chas       1.108047e-03
# nox        1.314957e-03
# rm         3.234334e-12
# age        7.842620e-01
# dis        1.150750e-08
# rad        7.308986e-05
# tax        4.694260e-03
# ptratio    3.881855e-07
# black      1.306714e-03
# lstat      1.070055e-18
# dtype: float64

# %% [markdown]
# - age 제거

# %%
X=X.drop(['age'],axis=1)
model=sm.OLS(y, X).fit()
model.pvalues
# Out:
# const      9.409352e-08
# crim       3.293555e-01
# zn         4.594669e-03
# indus      4.636234e-01
# chas       1.112687e-03
# nox        6.583172e-04
# rm         1.247794e-12
# dis        1.923356e-09
# rad        5.755337e-05
# tax        4.261551e-03
# ptratio    2.947872e-07
# black      1.330265e-03
# lstat      1.041730e-20
# dtype: float64

# %% [markdown]
# - indus 제거

# %%
X=X.drop(['indus'],axis=1)
model=sm.OLS(y, X).fit()
model.pvalues
# Out:
# const      1.088757e-07
# crim       3.008755e-01
# zn         5.471297e-03
# chas       8.930414e-04
# nox        8.538017e-04
# rm         1.513440e-12
# dis        2.513821e-10
# rad        6.822808e-05
# tax        4.766563e-03
# ptratio    3.732191e-07
# black      1.454475e-03
# lstat      1.081310e-20
# dtype: float64

# %% [markdown]
# - crim 제거

# %%
X=X.drop(['crim'],axis=1)
model=sm.OLS(y, X).fit()
model.pvalues
# Out:
# const      1.706257e-07
# zn         7.098549e-03
# chas       7.947973e-04
# nox        1.139002e-03
# rm         1.030853e-12
# dis        3.890661e-10
# rad        1.085638e-04
# tax        5.657253e-03
# ptratio    4.607103e-07
# black      3.617768e-04
# lstat      1.537228e-22
# dtype: float64

# %%
X=X.drop(['const'],axis=1)

# %%
calc_vif(X)
# Out:
#   variables        VIF
# 0        zn   2.471216
# 1      chas   1.123728
# 2       nox  65.579469
# 3        rm  75.929875
# 4       dis  11.992897
# 5       rad  12.005239
# 6       tax  45.710195
# 7   ptratio  84.119383
# 8     black  21.490905
# 9     lstat   9.419972

# %% [markdown]
# - ptratio 제거

# %%
X=X.drop(['ptratio'],axis=1)
calc_vif(X)
# Out:
#   variables        VIF
# 0        zn   2.122294
# 1      chas   1.108099
# 2       nox  65.496130
# 3        rm  58.792941
# 4       dis  10.302051
# 5       rad  12.005180
# 6       tax  42.601015
# 7     black  19.869245
# 8     lstat   8.240651

# %% [markdown]
# - nox 제거

# %%
X=X.drop(['nox'],axis=1)
calc_vif(X)
# Out:
#   variables        VIF
# 0        zn   2.080954
# 1      chas   1.102438
# 2        rm  31.226078
# 3       dis   8.963349
# 4       rad  11.871043
# 5       tax  36.894450
# 6     black  19.527500
# 7     lstat   6.124816

# %% [markdown]
# - tax 제거

# %%
X=X.drop(['tax'],axis=1)
calc_vif(X)
# Out:
#   variables        VIF
# 0        zn   2.075234
# 1      chas   1.095537
# 2        rm  26.262851
# 3       dis   8.865402
# 4       rad   3.324742
# 5     black  19.203768
# 6     lstat   5.028412

# %% [markdown]
# - rm 제거

# %%
X=X.drop(['rm'],axis=1)
calc_vif(X)
# Out:
#   variables       VIF
# 0        zn  2.074683
# 1      chas  1.084786
# 2       dis  7.713287
# 3       rad  2.888837
# 4     black  8.927402
# 5     lstat  4.848471

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

lin_reg = LinearRegression()
scores = cross_val_score(lin_reg, X, y, cv=5, scoring='neg_mean_absolute_error')

## neg_root_mean_squared_error

scores
# Out:
# array([-3.134203  , -4.42735918, -5.59407829, -4.94504329, -3.7983439 ])

# %%
scores.mean()
# Out:
# -4.379805530344058

# %% [markdown]
# ### 모두 넣고 수행 해보기

# %%
boston_ind = boston.drop(['medv'],axis=1)

scores_all = cross_val_score(lin_reg, boston_ind, y, cv=5, scoring='neg_mean_absolute_error')
scores_all
# Out:
# array([-2.66002906, -4.04621851, -4.22494518, -6.08784855, -7.24810396])

# %%
scores_all.mean()
# Out:
# -4.853429054378493

# %%
boston_ind
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4    0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 328  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       18.7  394.63   2.94
# 3       18.7  396.90   5.33
# 4       15.2  395.60  12.43
# ..       ...     ...    ...
# 328     19.2  395.77  15.10
# 329     21.0  391.99   9.67
# 330     21.0  396.90   9.08
# 331     21.0  396.90   5.64
# 332     21.0  396.90   7.88
#
# [333 rows x 13 columns]

# %%
boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4    0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 328  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       18.7  394.63   2.94  33.4
# 3       18.7  396.90   5.33  36.2
# 4       15.2  395.60  12.43  22.9
# ..       ...     ...    ...   ...
# 328     19.2  395.77  15.10  17.5
# 329     21.0  391.99   9.67  22.4
# 330     21.0  396.90   9.08  20.6
# 331     21.0  396.90   5.64  23.9
# 332     21.0  396.90   7.88  11.9
#
# [333 rows x 14 columns]
